# %%
import ./../../SpecTools
# Out:
#   File "<ipython-input-2-7c01a47eb2e1>", line 1
#     import ./../../SpecTools
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Loading and plotting raw data

# %%
# %cd '/Users/alexbeecher/Documents/Owen lab/AB3/095/AB3-095'
reac95 = reaction('.', molarity0 = 1.8289)
reac95.plot_spectrasbs(window = [3.0,4.5], subset = [0,36])
savefig('../rawplots_subset.pdf', dpi = 300)
# Out:
# /Users/alexbeecher/Documents/Owen lab/AB3/095/AB3-095

# %% [markdown]
# #### Selecting a single spectrum, choosing a window, and comparing constrained and unconstrained fitting functions

# %%
spec = reac95[reac95.keys()[0]]
spec.set_window([4.2,3.1])
spec.crunch()
savefig('../unconstrainedsingle_3.1_4.2.png', dpi = 300)
spec.crunch2(numpeaks = 3, window = [4.2, 3.1])
fig = spec.plot_all()
fig.savefig('../constrainedsingle_3pks_3.1_4.2.png', dpi = 300)
# Out:
# Fitting Sample8366
# Adding a gauss at 3.33290841398
# Fitting Sample8366
# Adding a gauss at 3.32397300268
# Fitting Sample8366
# Adding a gauss at 3.18725431877
# Fitting Sample8366
# Adding a gauss at 4.1054368543
# Fitting Sample8366
# Adding a gauss at 3.53231319088
# Fitting Sample8366
# Adding a gauss at 3.42497770718
# Fitting Sample8366
# Adding a gauss at 4.1054368543
# Fitting Sample8366
# Adding a gauss at 3.30624514667
# Fitting Sample8366
# Removing a gauss at 3.43726191517 for amplitude '-1.97147354754' against value '0.00457611803043'
# Removing a gauss at 3.37917378365 for amplitude '-0.483780578095' against value '0.00457611803043'
# Removing a feature
# Removing a feature
# Fitting Sample8366
# Removing a gauss at 3.23123717408 for amplitude '-0.282600798443' against value '0.00457611803043'
# Removing a gauss at 3.12720861549 for amplitude '-0.623339072501' against value '0.00457611803043'
# Removing a feature
# Removing a feature
# Fitting Sample8366
# ...

# %% [markdown]
# #### Selecting a single spectrum, choosing a different window, and comparing constrained and unconstrained fitting functions

# %%
reac95 = reaction('.', molarity0 = 1.8289)
spec = reac95[reac95.keys()[0]]
spec.set_window([3.8,3.2])
spec.crunch(lookahead = 5)
savefig('../unconstrainedsingle3.2_3.8.png', dpi = 300)
spec.crunch2(lookahead = 5, window = [3.8,3.2], numpeaks=3)
fig = spec.plot_all()
fig.savefig('../constrainedsingle_3pks_3.2_3.8.png', dpi = 300)
# Out:
# Fitting Sample8366
# Adding a gauss at 3.79156553517
# Fitting Sample8366
# Adding a gauss at 3.42497770718
# Fitting Sample8366
# Adding a gauss at 3.23718519582
# Fitting Sample8366
# Adding a gauss at 3.52227821023
# Fitting Sample8366
# Adding a gauss at 3.22875502604
# Fitting Sample8366
# Adding a gauss at 3.22036864935
# Fitting Sample8366
# Fitting Sample8366
# Adding a gauss at 3.79156553517
# Fitting Sample8366

# %% [markdown]
# #### CAN IGNORE: Based off window and numpeaks determined in previous cells, fit entire reaction. No informnext function.

# %%
# %cd '/Users/alexbeecher/Documents/Owen lab/AB3/095/AB3-095'
reac95 = reaction('.', molarity0 = 1.8289)
reac95.fit_reaction(numpeaks = 3, window = [3.4, 4.3], lookahead = 5)
fig = reac95.plot_spectrafitssbs()
#fig.savefig('../reacfit_3pks_3.4_4.3.png', dpi = 300)
fig2 = reac95.plot_fitresultssbs()
#fig2.savefig('../fitparams_3pks_3.4_4.3.png', dpi = 300)
# Out:
# /Users/alexbeecher/Documents/Owen lab/AB3/095/AB3-095
# Fitting Sample8246
# Removing a gauss at 3.57833840321 for amplitude '-0.196364077755' against value '0.00023865533495'
# Removing a feature
# Fitting Sample8246
# Adding a gauss at 3.56276416667
# Fitting Sample8246
# Adding a gauss at 3.55255567335
# Fitting Sample8246
# Fitting Sample8247
# Adding a gauss at 3.79156553517
# Fitting Sample8247
# Fitting Sample8248
# Adding a gauss at 3.79156553517
# Fitting Sample8248
# Fitting Sample8249
# Adding a gauss at 3.79156553517
# Fitting Sample8249
# Fitting Sample8250
# Adding a gauss at 3.79156553517
# Fitting Sample8250
# Fitting Sample8251
# Adding a gauss at 3.79156553517
# Fitting Sample8251
# Fitting Sample8252
# Adding a gauss at 3.80319610429
# Fitting Sample8252
# Fitting Sample8253
# Adding a gauss at 4.29011048443
# Fitting Sample8253
# Fitting Sample8254
# Adding a gauss at 3.58335817919
# Fitting Sample8254
# Fitting Sample8255
# Adding a gauss at 3.79156553517
# ...

# %% [markdown]
# #### Same as previous, but with informnext on

# %%
# %cd '/Users/alexbeecher/Documents/Owen lab/AB3/095/AB3-095'
reac95 = reaction('.', molarity0 = 1.8289)
reac95.fit_reaction(numpeaks = 3, window = [4.2, 3.1], lookahead = 5, informnext = True)
#fig = reac95.plot_spectrafitssbs()
#fig.savefig('../reacfit_3pks_3.1_4.2_in.png', dpi = 300)
#fig2 = reac95.plot_fitresultssbs(subset = [0,30])
#fig2.savefig('../fitparams_3pks_3.1_4.2_in.png', dpi = 300)
#fig3 = reac95.plot_fitresultscollapsed(feat_list = [0,1])
#fig3.savefig('../fitplot_mainpks_3pks_3.1_4.2_in.png', dpi = 300)
# Out:
# /Users/alexbeecher/Documents/Owen lab/AB3/095/AB3-095
# Fitting Sample8366
# Adding a gauss at 3.32397300268
# Fitting Sample8366
# Fitting Sample8367
# Fitting Sample8368
# Fitting Sample8369
# Fitting Sample8370
# Fitting Sample8371
# Fitting Sample8372
# Fitting Sample8373
# Fitting Sample8374
# Fitting Sample8375
# Fitting Sample8376
# Fitting Sample8377
# Fitting Sample8378
# Fitting Sample8379
# Fitting Sample8380
# Fitting Sample8381
# Fitting Sample8382
# Fitting Sample8383
# Fitting Sample8384
# Fitting Sample8385
# Fitting Sample8386
# Fitting Sample8387
# Fitting Sample8388
# Fitting Sample8389
# Fitting Sample8390
# Fitting Sample8391
# Fitting Sample8392
# Fitting Sample8393
# Fitting Sample8394
# Fitting Sample8395
# Fitting Sample8396
# Fitting Sample8397
# Fitting Sample8398
# Fitting Sample8399
# Fitting Sample8400
# Fitting Sample8401
# Fitting Sample8402
# Fitting Sample8403
# Fitting Sample8404
# Fitting Sample8405
# Fitting Sample8406
# ...

# %%
#subset = [0,20]
#print reac95.results['Peak 0 Amplitude'].values[range(*subset)]
fig2 = reac95.plot_fitresultssbs()
fig2 = reac95.plot_fitresultssbs(subset = [0,30])

# %%
fig2 = reac95.plot_fitresultscollapsed(feat_list = [0,1], subset = [0,36])
fig2.savefig('../fitplot_mainpks_3pks_3.1_4.2_in.pdf', dpi = 300)

# %% [markdown]
# #### Same as previous, but with fixed background on

# %%
# %cd '/Users/alexbeecher/Documents/Owen lab/AB3/095/AB3-095'
reac95 = reaction('.', molarity0 = 1.8289)
spec = reac95[reac95.keys()[0]]
reac95.fit_reaction(numpeaks = 3, window = [4.2, 3.1], lookahead = 5, informnext = True, fix_bkgrd = True)
fig = reac95.plot_spectrafitssbs()
fig.savefig('../reacfit_3pks_3.1_4.2_in_bkg.png', dpi = 300)
fig2 = reac95.plot_fitresultssbs()
fig2.savefig('../fitparams_3pks_3.1_4.2_in_bkg.png', dpi = 300)
fig3 = reac95.plot_fitresultscollapsed(feat_list = [0,1])
fig3.savefig('../fitplot_mainpks_3pks_3.1_4.2_in_bkg.png', dpi = 300)
# Out:
# /Users/alexbeecher/Documents/Owen lab/AB3/095/AB3-095
# Fitting Sample8366
# Adding a gauss at 3.32397300268
# Fitting Sample8366
# Fitting Sample8367
# Fitting Sample8368
# Fitting Sample8369
# Fitting Sample8370
# Fitting Sample8371
# Fitting Sample8372
# Fitting Sample8373
# Fitting Sample8374
# Fitting Sample8375
# Fitting Sample8376
# Fitting Sample8377
# Fitting Sample8378
# Fitting Sample8379
# Fitting Sample8380
# Fitting Sample8381
# Fitting Sample8382
# Fitting Sample8383
# Fitting Sample8384
# Fitting Sample8385
# Fitting Sample8386
# Fitting Sample8387
# Fitting Sample8388
# Fitting Sample8389
# Fitting Sample8390
# Fitting Sample8391
# Fitting Sample8392
# Fitting Sample8393
# Fitting Sample8394
# Fitting Sample8395
# Fitting Sample8396
# Fitting Sample8397
# Fitting Sample8398
# Fitting Sample8399
# Fitting Sample8400
# Fitting Sample8401
# Fitting Sample8402
# Fitting Sample8403
# Fitting Sample8404
# Fitting Sample8405
# Fitting Sample8406

# %% [markdown]
# #### CAN IGNORE Smaller window, fewer peaks, no informnext

# %%
# %cd '/Users/alexbeecher/Documents/Owen lab/AB3/095/AB3-095'
reac95 = reaction('.', molarity0 = 1.8289)
reac95.fit_reaction(numpeaks = 3, window = [3.2, 3.8], lookahead = 5)
fig = reac95.plot_spectrafitssbs()
fig.savefig('../reacfit_3pks_3.2_3.8.png', dpi = 300)
fig2 = reac95.plot_fitresultssbs()
fig2.savefig('../fitparams_3pks_3.2_3.8.png', dpi = 300)
# Out:
# /Users/alexbeecher/Documents/Owen lab/AB3/095/AB3-095
# Fitting Sample8287
# Adding a gauss at 3.99949009677
# Fitting Sample8287
# Fitting Sample8288
# Adding a gauss at 3.99949009677
# Fitting Sample8288
# Fitting Sample8289
# Adding a gauss at 3.99949009677
# Fitting Sample8289
# Fitting Sample8290
# Adding a gauss at 3.99949009677
# Fitting Sample8290
# Fitting Sample8295
# Adding a gauss at 3.99949009677
# Fitting Sample8295
# Fitting Sample8292
# Adding a gauss at 3.99949009677
# Fitting Sample8292
# Fitting Sample8295
# Adding a gauss at 3.99949009677
# Fitting Sample8295
# Fitting Sample8294
# Adding a gauss at 3.99949009677
# Fitting Sample8294
# Fitting Sample8295
# Adding a gauss at 3.99949009677
# Fitting Sample8295
# Fitting Sample8296
# Adding a gauss at 3.99949009677
# Fitting Sample8296
# Fitting Sample8297
# Adding a gauss at 3.99949009677
# Fitting Sample8297
# Fitting Sample8298
# Adding a gauss at 3.99949009677
# Fitting Sample8298
# Fitting Sample8299
# ...

# %% [markdown]
# #### Same as previous with informnext

# %%
# %cd '/Users/alexbeecher/Documents/Owen lab/AB3/095/AB3-095'
reac95 = reaction('.', molarity0 = 1.8289)
reac95.fit_reaction(window = [3.2, 3.8], numpeaks = 3, lookahead = 5, informnext = True)
fig = reac95.plot_spectrafitssbs()
fig.savefig('../reacfit_3pks_3.2_3.8_in.png', dpi = 300)
fig2 = reac95.plot_fitresultssbs()
fig2.savefig('../fitparams_3pks_3.2_3.8_in.png', dpi = 300)
fig3 = reac95.plot_fitresultscollapsed(feat_list = [0,1])
fig3.savefig('../fitplot_mainpks_3pks_3.2_3.8_in.png', dpi = 300)
# Out:
# /Users/alexbeecher/Documents/Owen lab/AB3/095/AB3-095
# Fitting Sample8366
# Adding a gauss at 3.79156553517
# Fitting Sample8366
# Fitting Sample8367
# Fitting Sample8368
# Fitting Sample8369
# Fitting Sample8370
# Fitting Sample8371
# Fitting Sample8372
# Fitting Sample8373
# Fitting Sample8374
# Fitting Sample8375
# Fitting Sample8376
# Fitting Sample8377
# Fitting Sample8378
# Fitting Sample8379
# Fitting Sample8380
# Fitting Sample8381
# Fitting Sample8382
# Fitting Sample8383
# Fitting Sample8384
# Fitting Sample8385
# Fitting Sample8386
# Fitting Sample8387
# Fitting Sample8388
# Fitting Sample8389
# Fitting Sample8390
# Fitting Sample8391
# Fitting Sample8392
# Fitting Sample8393
# Fitting Sample8394
# Fitting Sample8395
# Fitting Sample8396
# Fitting Sample8397
# Fitting Sample8398
# Fitting Sample8399
# Fitting Sample8400
# Fitting Sample8401
# Fitting Sample8402
# Fitting Sample8403
# Fitting Sample8404
# Fitting Sample8405
# Fitting Sample8406

# %% [markdown]
# #### Same as previous but with fixed background

# %%
# %cd '/Users/alexbeecher/Documents/Owen lab/AB3/095/AB3-095'
reac95 = reaction('.', molarity0 = 1.8289)
reac95.fit_reaction(numpeaks = 3, window = [3.2, 3.8], lookahead = 5, fix_bkgrd = True, informnext = True)
fig = reac95.plot_spectrafitssbs()
fig.savefig('../reacfit_3pks_3.2_3.8_in_bkg.png', dpi = 300)
fig2 = reac95.plot_fitresultssbs()
fig2.savefig('../fitparams_3pks_3.2_3.8_in_bkg.png', dpi = 300)
fig3 = reac95.plot_fitresultscollapsed(feat_list = [0,1])
fig3.savefig('../fitplot_mainpks_3pks_3.2_3.8_in_bkg.png', dpi = 300)
# Out:
# /Users/alexbeecher/Documents/Owen lab/AB3/095/AB3-095
# Fitting Sample8366
# Adding a gauss at 3.79156553517
# Fitting Sample8366
# Fitting Sample8367
# Fitting Sample8368
# Fitting Sample8369
# Fitting Sample8370
# Fitting Sample8371
# Fitting Sample8372
# Fitting Sample8373
# Fitting Sample8374
# Fitting Sample8375
# Fitting Sample8376
# Fitting Sample8377
# Fitting Sample8378
# Fitting Sample8379
# Fitting Sample8380
# Fitting Sample8381
# Fitting Sample8382
# Fitting Sample8383
# Fitting Sample8384
# Fitting Sample8385
# Fitting Sample8386
# Fitting Sample8387
# Fitting Sample8388
# Fitting Sample8389
# Fitting Sample8390
# Fitting Sample8391
# Fitting Sample8392
# Fitting Sample8393
# Fitting Sample8394
# Fitting Sample8395
# Fitting Sample8396
# Fitting Sample8397
# Fitting Sample8398
# Fitting Sample8399
# Fitting Sample8400
# Fitting Sample8401
# Fitting Sample8402
# Fitting Sample8403
# Fitting Sample8404
# Fitting Sample8405
# Fitting Sample8406
